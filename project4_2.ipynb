# %% [markdown]
# <a href="https://colab.research.google.com/github/dyhwang7/CS4650/blob/main/project4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (1.3.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (4.2.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (2.23.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.10)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as web
import datetime as dt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
tickers = ['AAPL', 'FB', 'MSFT', 'GOOGL', 'V', 'DIS']

# 'NVDA', 'MSFT', 'FB', 'RBLX', 'LCID', 'BABA', 'GOOGL', 'PYPL', 'V', 'DIS'
start = dt.datetime(2018, 1, 1)
end = dt.datetime(2021, 1, 1)

data = []

for t in tickers:
  data.append(web.DataReader(t, 'yahoo', start, end))

for index, val in enumerate(data):
  stock_prediction(index, val)
# Out:
# Epoch 1/25
# 22/22 [==============================] - 8s 106ms/step - loss: 0.0290
# Epoch 2/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0056
# Epoch 3/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0040
# Epoch 4/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0042
# Epoch 5/25
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0043
# Epoch 6/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0044
# Epoch 7/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0035
# Epoch 8/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0035
# Epoch 9/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0032
# Epoch 10/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0032
# Epoch 11/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0033
# Epoch 12/25
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0035
# Epoch 13/25
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0027
# Epoch 14/25
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0029
# Epoch 15/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0028
# Epoch 16/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0024
# Epoch 17/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0024
# Epoch 18/25
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0030
# Epoch 19/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0034
# Epoch 20/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0021
# Epoch 21/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0031
# Epoch 22/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0024
# Epoch 23/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0021
# Epoch 24/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0022
# Epoch 25/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0022
# Epoch 1/25
# 22/22 [==============================] - 9s 109ms/step - loss: 0.0459
# Epoch 2/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0104
# Epoch 3/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0075
# Epoch 4/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0067
# Epoch 5/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0061
# Epoch 6/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0056
# Epoch 7/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0059
# Epoch 8/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0055
# Epoch 9/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0055
# Epoch 10/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0048
# Epoch 11/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0051
# Epoch 12/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0057
# Epoch 13/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0048
# Epoch 14/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0047
# Epoch 15/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0048
# Epoch 16/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0045
# Epoch 17/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0041
# Epoch 18/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0046
# Epoch 19/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0043
# Epoch 20/25
# 22/22 [==============================] - 2s 102ms/step - loss: 0.0043
# Epoch 21/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0043
# Epoch 22/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0043
# Epoch 23/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0040
# Epoch 24/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0041
# Epoch 25/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0039
# Epoch 1/25
# 22/22 [==============================] - 8s 103ms/step - loss: 0.0361
# Epoch 2/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0068
# Epoch 3/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0059
# Epoch 4/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0048
# Epoch 5/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0047
# Epoch 6/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0040
# Epoch 7/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0045
# Epoch 8/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0052
# Epoch 9/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0044
# Epoch 10/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0043
# Epoch 11/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0038
# Epoch 12/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0042
# Epoch 13/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0041
# Epoch 14/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0044
# Epoch 15/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0039
# Epoch 16/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0034
# Epoch 17/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0041
# Epoch 18/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0049
# Epoch 19/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0037
# Epoch 20/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0045
# Epoch 21/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0035
# Epoch 22/25
# 22/22 [==============================] - 2s 104ms/step - loss: 0.0045
# Epoch 23/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0031
# Epoch 24/25
# 22/22 [==============================] - 2s 105ms/step - loss: 0.0033
# Epoch 25/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0035
# Epoch 1/25
# 22/22 [==============================] - 10s 108ms/step - loss: 0.0522
# Epoch 2/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0109
# Epoch 3/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0081
# Epoch 4/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0070
# Epoch 5/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0069
# Epoch 6/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0063
# Epoch 7/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0058
# Epoch 8/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0050
# Epoch 9/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0056
# Epoch 10/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0059
# Epoch 11/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0055
# Epoch 12/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0048
# Epoch 13/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0046
# Epoch 14/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0046
# Epoch 15/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0048
# Epoch 16/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0044
# Epoch 17/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0042
# Epoch 18/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0040
# Epoch 19/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0039
# Epoch 20/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0039
# Epoch 21/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0044
# Epoch 22/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0035
# Epoch 23/25
# 22/22 [==============================] - 2s 106ms/step - loss: 0.0038
# Epoch 24/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0037
# Epoch 25/25
# 22/22 [==============================] - 2s 107ms/step - loss: 0.0040
# Epoch 1/25
# 22/22 [==============================] - 8s 111ms/step - loss: 0.0763
# Epoch 2/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0139
# Epoch 3/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0092
# Epoch 4/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0075
# Epoch 5/25
# 22/22 [==============================] - 3s 113ms/step - loss: 0.0077
# Epoch 6/25
# 22/22 [==============================] - 3s 116ms/step - loss: 0.0074
# Epoch 7/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0072
# Epoch 8/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0070
# Epoch 9/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0062
# Epoch 10/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0071
# Epoch 11/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0070
# Epoch 12/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0065
# Epoch 13/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0066
# Epoch 14/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0069
# Epoch 15/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0067
# Epoch 16/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0060
# Epoch 17/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0056
# Epoch 18/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0054
# Epoch 19/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0059
# Epoch 20/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0052
# Epoch 21/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0060
# Epoch 22/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0050
# Epoch 23/25
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0053
# Epoch 24/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0057
# Epoch 25/25
# 22/22 [==============================] - 2s 108ms/step - loss: 0.0044
# Epoch 1/25
# 22/22 [==============================] - 10s 116ms/step - loss: 0.0271
# Epoch 2/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0090
# Epoch 3/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0067
# Epoch 4/25
# 22/22 [==============================] - 2s 110ms/step - loss: 0.0067
# Epoch 5/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0054
# Epoch 6/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0054
# Epoch 7/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0052
# Epoch 8/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0046
# Epoch 9/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0049
# Epoch 10/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0043
# Epoch 11/25
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0045
# Epoch 12/25
# 22/22 [==============================] - 3s 118ms/step - loss: 0.0039
# Epoch 13/25
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0040
# Epoch 14/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0043
# Epoch 15/25
# 22/22 [==============================] - 2s 111ms/step - loss: 0.0039
# Epoch 16/25
# 22/22 [==============================] - 3s 115ms/step - loss: 0.0044
# Epoch 17/25
# 22/22 [==============================] - 3s 117ms/step - loss: 0.0032
# Epoch 18/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0036
# Epoch 19/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0036
# Epoch 20/25
# 22/22 [==============================] - 2s 112ms/step - loss: 0.0036
# Epoch 21/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0032
# Epoch 22/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0036
# Epoch 23/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0039
# Epoch 24/25
# 22/22 [==============================] - 2s 113ms/step - loss: 0.0035
# Epoch 25/25
# 22/22 [==============================] - 3s 114ms/step - loss: 0.0034

# %%
def stock_prediction(index, data):
  scaler = MinMaxScaler(feature_range=(0,1))
  scaled_data = scaler.fit_transform(data['Close'].values.reshape(-1,1))

  prediction_days = 60
  x_train = []
  y_train = []

  for x in range(prediction_days, len(scaled_data)):
    x_train.append(scaled_data[x-prediction_days:x, 0])
    y_train.append(scaled_data[x, 0])

  x_train, y_train = np.array(x_train), np.array(y_train)
  x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


  model = Sequential()
  model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
  model.add(Dropout(0.2))
  model.add(LSTM(units=50, return_sequences=True))
  model.add(Dropout(0.2))
  model.add(LSTM(units=50))
  model.add(Dropout(0.2))
  model.add(Dense(units=1))

  model.compile(optimizer='adam', loss='mean_squared_error')
  model.fit(x_train, y_train, epochs=25, batch_size=32)
  test_start = dt.datetime(2020, 1, 1)
  test_end = dt.datetime(2021, 11, 30)

  test_data = web.DataReader(tickers[index], 'yahoo', test_start, test_end)
  actual_prices = test_data['Close'].values

  total_dataset = pd.concat((data['Close'], test_data['Close']), axis=0)

  model_inputs = total_dataset[len(total_dataset) - len(test_data) - prediction_days:].values
  model_inputs = model_inputs.reshape(-1, 1)
  model_inputs = scaler.transform(model_inputs)

  x_test = []

  for x in range(prediction_days, len(model_inputs)):
    x_test.append(model_inputs[x-prediction_days:x, 0])

  x_test = np.array(x_test)
  x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

  predicted_prices = model.predict(x_test)
  predicted_prices = scaler.inverse_transform(predicted_prices)

  company = tickers[index]
  plt.plot(actual_prices, color="black", label=f"Actual {company} Price")
  plt.plot(predicted_prices, color="orange", label=f"Predicted {company} Price")
  plt.title(f"{company} Share Price")
  plt.xlabel('Time')
  plt.ylabel(f'{company} Share Price')
  plt.legend()
  plt.show()

  # real_data = [model_inputs[len(model_inputs) + 1 - prediction_days:len(model_inputs+1), 0]]
  # real_data = np.array(real_data)
  # real_data = np.reshape(real_data, (real_data.shape[0], real_data.shape[1], 1))

  # print(real_data, len(real_data))

  # prediction = model.predict(real_data)
  # prediction = scaler.inverse_transform(prediction)
  # print(f"Prediction: {prediction}")
